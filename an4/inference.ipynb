# %%
#  Compatibility imports
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function


import time

import tensorflow as tf
import scipy.io.wavfile as wav
import numpy as np
import os

from six.moves import xrange as range

try:
    from tensorflow.python.ops import ctc_ops
except ImportError:
    from tensorflow.contrib.ctc import ctc_ops

try:
    from python_speech_features import mfcc
except ImportError:
    print("Failed to import python_speech_features.\n Try pip install python_speech_features.")
    raise ImportError

from utils import maybe_download as maybe_download
from utils import sparse_tuple_from as sparse_tuple_from

# %%
def wer2(r, h): 

# taken from https://martin-thoma.com/word-error-rate-calculation/
    """
    Calculation of WER with Levenshtein distance.

    Works only for iterables up to 254 elements (uint8).
    O(nm) time ans space complexity.

    Parameters
    ----------
    r : list
    h : list

    Returns
    -------
    int

    Examples
    --------
    >>> wer("who is there".split(), "is there".split())
    1
    >>> wer("who is there".split(), "".split())
    3
    >>> wer("".split(), "who is there".split())
    3
    """
    # initialisation
    import numpy
    d = numpy.zeros((len(r)+1)*(len(h)+1), dtype=numpy.uint8)
    d = d.reshape((len(r)+1, len(h)+1))
    for i in range(len(r)+1):
        for j in range(len(h)+1):
            if i == 0:
                d[0][j] = j
            elif j == 0:
                d[i][0] = i

    # computation
    for i in range(1, len(r)+1):
        for j in range(1, len(h)+1):
            if r[i-1] == h[j-1]:
                d[i][j] = d[i-1][j-1]
            else:
                substitution = d[i-1][j-1] + 1
                insertion    = d[i][j-1] + 1
                deletion     = d[i-1][j] + 1
                d[i][j] = min(substitution, insertion, deletion)

    return d[len(r)][len(h)]

# %%
# Constants
SPACE_TOKEN = '<space>'
SPACE_INDEX = 0
FIRST_INDEX = ord('a') - 1  # 0 is reserved to space

# Some configs
num_features = 13
# Accounting the 0th indice +  space + blank label = 28 characters
num_classes = ord('z') - ord('a') + 1 + 1 + 1

# Hyper-parameters
num_epochs = 5
num_hidden = 50
num_layers = 2
batch_size = 1
initial_learning_rate = 7e-5
momentum = 0.9

# %%
# Loading the data
from os import listdir
from os.path import isfile, join

mypath='/home/saurabh/Documents/ctc_tensorflow_new/an4/data'
data_files = [f for f in listdir(mypath) if isfile(join(mypath, f))]
txt_files = [ fi for fi in data_files if not fi.endswith(".wav") ]
txt_files = lst = [os.path.splitext(x)[0] for x in txt_files]
wav_files = [ fi for fi in data_files if not fi.endswith(".txt") ]
wav_files = lst = [os.path.splitext(x)[0] for x in wav_files]

num_examples = len(wav_files)
print ("number of data examples : " + str(num_examples) )
num_batches_per_epoch = int(num_examples/batch_size)


#print (wav_files)
audio_filename={}
target_filename={}
fs={}
audio={}
inputs={}
train_inputs={}
train_seq_len = {}
targets={}
train_targets={}
original={}
# Out:
# number of data examples : 948

# %%
for i,j in enumerate(wav_files):
        #print (i,j)
	audio_filename[i] =  '/home/saurabh/Documents/ctc_tensorflow_new/an4/data/' + j + '.wav'
	#print ( audio_filename[i])
	#print (audio_filename)
	target_filename[i] =  '/home/saurabh/Documents/ctc_tensorflow_new/an4/data/' + j + '.txt'
	fs[i], audio[i] = wav.read( audio_filename[i])
	#print (audio[i])

	
	#print (temp2)
	inputs[i] = mfcc(audio[i], samplerate=fs[i])
	#print ( inputs[i].shape , fs[i] )
	temp=inputs[i]
	# Tranform in 3D array
	
	train_inputs[i] = np.asarray(temp[np.newaxis, :])
	train_seq_len[i]=[train_inputs[i].shape[1]]
	#print ("new shape " + str(train_inputs[i].shape))
	with open(target_filename[i], 'r') as f:
    
   	 #Only the last line is necessary
    		line = f.readlines()[-1]    

   	 # Get only the words between [a-z] and replace period for none
    		original[i] = ' '.join(line.strip().lower().split(' ')).replace('.', '')
    		targets[i] = original[i].replace(' ', '  ')
    		targets[i] = targets[i].split(' ')
    	#np.append(Targets,targets)

	# Adding blank label
		targets[i] = np.hstack([SPACE_TOKEN if x == '' else list(x) for x in targets[i]])


	# Transform char into index
		targets[i] = np.asarray([SPACE_INDEX if x == SPACE_TOKEN else ord(x) - FIRST_INDEX
                      for x in targets[i]])
	


	# Creating sparse representation to feed the placeholder

		train_targets[i] = sparse_tuple_from([targets[i]])

# %%
val_inputs, val_targets, val_seq_len = train_inputs, train_targets, \
                                       train_seq_len

# %%
graph = tf.Graph()
with graph.as_default():
    # e.g: log filter bank or MFCC features
    # Has size [batch_size, max_stepsize, num_features], but the
    # batch_size and max_stepsize can vary along each step
    inputs = tf.placeholder(tf.float32, [None, None, num_features])

    # Here we use sparse_placeholder that will generate a
    # SparseTensor required by ctc_loss op.
    targets = tf.sparse_placeholder(tf.int32)

    # 1d array of size [batch_size]
    seq_len = tf.placeholder(tf.int32, [None])

    # Defining the cell
    # Can be:
    #   tf.nn.rnn_cell.RNNCell
    #   tf.nn.rnn_cell.GRUCell
    cell = tf.contrib.rnn.BasicLSTMCell(num_hidden, state_is_tuple=True)

    # Stacking rnn cells
    #[[cell] for _ in range(num_layers)]
    stack =  tf.contrib.rnn.MultiRNNCell([cell] * num_layers,
                                       state_is_tuple=True)

    #stack =  tf.contrib.rnn.MultiRNNCell([[cell] for _ in range(num_layers)],
                                       # state_is_tuple=True)

    # The second output is the last state and we will no use that
    outputs, _ = tf.nn.dynamic_rnn(stack, inputs, seq_len, dtype=tf.float32)

    shape = tf.shape(inputs)
    batch_s, max_timesteps = shape[0], shape[1]

    # Reshaping to apply the same weights over the timesteps
    outputs = tf.reshape(outputs, [-1, num_hidden])

    # Truncated normal with mean 0 and stdev=0.1
    # Tip: Try another initialization
    # see https://www.tensorflow.org/versions/r0.9/api_docs/python/contrib.layers.html#initializers
    W = tf.Variable(tf.truncated_normal([num_hidden,
                                         num_classes],
                                        stddev=0.1))
    # Zero initialization
    # Tip: Is tf.zeros_initializer the same?
    b = tf.Variable(tf.constant(0., shape=[num_classes]))

    # Doing the affine projection
    logits = tf.matmul(outputs, W) + b

    # Reshaping back to the original shape
    logits = tf.reshape(logits, [batch_s, -1, num_classes])

    # Time major
    logits = tf.transpose(logits, (1, 0, 2))

    loss = ctc_ops.ctc_loss( targets, logits , seq_len)
    cost = tf.reduce_mean(loss)

    optimizer = tf.train.MomentumOptimizer(initial_learning_rate,
                                           0.9).minimize(cost)

    # Option 2: tf.contrib.ctc.ctc_beam_search_decoder
    # (it's slower but you'll get better results)
    decoded, log_prob = ctc_ops.ctc_greedy_decoder(logits, seq_len)

    # Inaccuracy: label error rate
    ler = tf.reduce_mean(tf.edit_distance(tf.cast(decoded[0], tf.int32),
                                          targets))

    saver = tf.train.Saver()

# %%
with tf.Session(graph=graph) as session:
    # Initializate the weights and biases
    init_op = tf.global_variables_initializer()

    #init_op.run()
    saver.restore(session, './orange15.ckpt')
    print("Model restored.")


   
    totalwer=0

	  
    for i in range(1, num_examples):

        
        feed2 = {inputs: train_inputs[i-1],
                    targets: train_targets[i-1],
                    seq_len: train_seq_len[i-1]}
        d = session.run(decoded[0], feed_dict=feed2)
        #print (d)
    	str_decoded = ''.join([chr(x) for x in np.asarray(d[1]) + FIRST_INDEX])
    	# Replacing blank label to none
    	str_decoded = str_decoded.replace(chr(ord('z') + 1), '')
    	# Replacing space label to space
    	str_decoded = str_decoded.replace(chr(ord('a') - 1), ' ')
    	
	print('Original:\n%s' % original[i-1])
        print('Decoded:\n%s' % str_decoded)
        totalwer=totalwer + wer2(original[i-1].split(),str_decoded.split())
      #  print(wer2(original[i-1].split(),str_decoded.split()))
	
    print("average wer = " + str(totalwer/num_examples))
# Out:
# Model restored.
# Original:
# one five two one seven
# Decoded:
# one five two one seven
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s bu r g
# Original:
# rubout h f d w q six two two
# Decoded:
# rubout eh kf b w  six twotwo
# Original:
# two two nine three
# Decoded:
# t t nine thre
# Original:
# b a r r y
# Decoded:
#   r r i
# Original:
# one five one four seven
# Decoded:
# one five one four seven
# Original:
# help
# Decoded:
# l
# Original:
# go
# Decoded:
# l
# Original:
# m a t t h e w
# Decoded:
# m a t t h  w
# Original:
# erase f h b k z sixty nine
# Decoded:
# rs   b k z sixty nine
# Original:
# thirty three
# Decoded:
# teirt tere
# Original:
# rubout n x f e eight nine six
# Decoded:
# rubout  s  f e eight nine six
# Original:
# c h r i s t o p h e r
# Decoded:
# c  r i s t o  h  r
# Original:
# one five two one three
# Decoded:
# one fie to one thire
# Original:
# t i m o t h y
# Decoded:
# tp i m o g  y
# Original:
# enter six
# Decoded:
# nter six
# Original:
# rubout l d r w twenty six
# Decoded:
# rubout l d r w wnt six
# Original:
# f e g b forty eight
# Decoded:
# f g b forteight
# Original:
# five t h a v e n u e
# Decoded:
# five t h igh t e n e
# Original:
# g r e e n
# Decoded:
# p r e  n
# Original:
# rubout v a n b x nine
# Decoded:
# rubout vh n b s nine
# Original:
# a m p e r e
# Decoded:
# h n t  r
# Original:
# one oh seven oh eight
# Decoded:
# one oh seven oh eight eg
# Original:
# one seven forty seven
# Decoded:
# one seven four seven
# Original:
# v e r o n a
# Decoded:
# p  r o n
# Original:
# one five two two one
# Decoded:
# one five two two one
# Original:
# one five two three two
# Decoded:
# one five tw thre two
# Original:
# m i c h a e l
# Decoded:
# n y c h  l
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s b u r t h
# Original:
# two six eight four four one eight
# Decoded:
# tw six eight four four one eight
# Original:
# y w a a m two
# Decoded:
# oy    m two
# Original:
# no
# Decoded:
# no
# Original:
# seven fifty five
# Decoded:
# seve fty five
# Original:
# rubout c t l e seventy six twelve
# Decoded:
# rubout c t l seven six toe
# Original:
# m o r e w o o d
# Decoded:
# m o r  w o  d
# Original:
# rubout w p f j d two six
# Decoded:
# rubout   f  d tw six
# Original:
# rubout s h k j five seven six
# Decoded:
# rubout s    five seven six
# Original:
# p i t t s b u r g h
# Decoded:
#  i t t s b  r g h
# Original:
# g c d o four
# Decoded:
#  c v  four
# Original:
# fifty seven fourteen a
# Decoded:
# fty seven fourt te e
# Original:
# r o b e r t
# Decoded:
# ro b r tw
# Original:
# enter three eighty six
# Decoded:
# nter threeight six
# Original:
# enter seventy one
# Decoded:
# enter sen one
# Original:
# rubout r r n a a ninety four
# Decoded:
# rubout r r n   niney four
# Original:
# one seven three six eight
# Decoded:
# one sieven thr six eight
# Original:
# ten twenty eight sixty nine
# Decoded:
# en twentyeight sixtey nine
# Original:
# six four five three three six four
# Decoded:
# six four five thre thre six four
# Original:
# s t e v e n
# Decoded:
# s t  v
# Original:
# four one two two six eight four four seven four
# Decoded:
# four one two two six eight four four seven four
# Original:
# b seven twenty five
# Decoded:
# b seven tenty five
# Original:
# march twenty fifth nineteen sixty seven
# Decoded:
# uretwe ftnte sixt seven
# Original:
# o u four seven twenty nine
# Decoded:
# ro b four seven twnt nine
# Original:
# one six oh six three
# Decoded:
# one six oh six thre
# Original:
# rubout q n r a j seven four eight
# Decoded:
# rubout t  r   seven four ight
# Original:
# b e c h t e l
# Decoded:
# b c  t l
# Original:
# august twenty second nineteen sixty one
# Decoded:
# oue  twnty sevenn nineten sixty one
# Original:
# p o m e r a n t z
# Decoded:
# p l n  r   t z
# Original:
# one five two four one
# Decoded:
# one five two four one
# Original:
# erase g w d k f six eighty eight
# Decoded:
# r g m  k f six eight eight
# Original:
# z eight oh two
# Decoded:
# c h o two
# Original:
# j o s e p h
# Decoded:
# j o s  gh
# Original:
# four one two four two two three five seven eight
# Decoded:
# four one two fortwo two thre five seven eight
# Original:
# j four thirty three
# Decoded:
# i four tfixty thre
# Original:
# one five two one three
# Decoded:
# one five two one thiree
# Original:
# forty three twenty three
# Decoded:
# fourt thre fwnty thre
# Original:
# seven may nineteen forty four
# Decoded:
# seven nine teen fourty four
# Original:
# enter four fifty one
# Decoded:
# nter four fity one
# Original:
# october thirtieth nineteen sixty one
# Decoded:
# tw thr ninete sixty one
# Original:
# rubout n b a k ninety six
# Decoded:
# rubout n b h  niney six
# Original:
# september fifteenth nineteen sixty five
# Decoded:
# stm tfo tenth neten sixty five
# Original:
# three six three oh nine six two
# Decoded:
# thre six three oh nine six thr
# Original:
# r i c h a r d
# Decoded:
# r i c h r b
# Original:
# b r a d f o r d w o o d s
# Decoded:
# b r h  f o r  tw o o b s
# Original:
# e f r o m
# Decoded:
# pl r o
# Original:
# r o y
# Decoded:
# r o y
# Original:
# five ten
# Decoded:
# five ten
# Original:
# rubout g u k e v nine
# Decoded:
# rubout  u   v in
# Original:
# seven fifteen nineteen seventy
# Decoded:
# seven fifte ninte siventy
# Original:
# one two four one
# Decoded:
# one two  four one
# Original:
# three four four
# Decoded:
# thre four four
# Original:
# no
# Decoded:
#
# Original:
# three oh one
# Decoded:
# thre oh one
# Original:
# seven seventeen fifty seven
# Decoded:
# sevenseventen tfty seven
# Original:
# enter seven thirty eight
# Decoded:
# eter seven thirty eight
# Original:
# enter five
# Decoded:
# ter five
# Original:
# p i t t s b u r g h
# Decoded:
#  t t sb r t h
# Original:
# b u r c h f e i l d a v e
# Decoded:
# u r c  tf i l z
# Original:
# i t h a c a
# Decoded:
# i t h  c
# Original:
# two oh one four six four six oh eight three
# Decoded:
# two o ine tour six four six oh eightte
# Original:
# enter eight four
# Decoded:
# nter eight four
# Original:
# enter four
# Decoded:
# nter four
# Original:
# one five two two one
# Decoded:
# one five two two one
# Original:
# t h o m a s
# Decoded:
# tg h o m  s
# Original:
# one five two one seven
# Decoded:
# one five two oe seven
# Original:
# no
# Decoded:
# l
# Original:
# enter six
# Decoded:
# nter six
# Original:
# enter fifty five
# Decoded:
# nter fty five
# Original:
# one five two one seven
# Decoded:
# one five two one seven
# Original:
# h a m p s h i r e
# Decoded:
# h  n g s  i r
# Original:
# n h o t q two eight three
# Decoded:
# n  o t  two eight shr
# Original:
# k a r e n
# Decoded:
#   r e n
# Original:
# a v m u four forty two
# Decoded:
#  e   four fory two
# Original:
# four four four eight four
# Decoded:
# four four four eight four
# Original:
# one eleven
# Decoded:
# one  e ul
# Original:
# one five two two seven
# Decoded:
# one five two two seven
# Original:
# ninth of september nineteen sixty four
# Decoded:
# nnine tw sevetwr nineten sixty four
# Original:
# d o w l i n g
# Decoded:
# e o  l i n
# Original:
# one five two two one
# Decoded:
# one five two two one
# Original:
# i d m h seven eight five
# Decoded:
# i b m h seven eight five
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s  u r g
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s u r g h
# Original:
# p i t t s b u r g h
# Decoded:
# p i t ts b u r g h
# Original:
# g two eighty nine
# Decoded:
# g two eighty ne
# Original:
# enter two six
# Decoded:
# enter two six
# Original:
# seven three one one three three eight
# Decoded:
# seven thre one one thr thre eight
# Original:
# b e r k e l e y
# Decoded:
#   r   l y
# Original:
# rubout f y n p ninety seven
# Decoded:
# ubout f y en g nine y seven
# Original:
# enter four fifty six
# Decoded:
# eter four fifty six
# Original:
# w a r r e n
# Decoded:
# w  r r  n
# Original:
# rubout z g d r g nine nine four six
# Decoded:
# rubout z g d r g nine nine four six
# Original:
# q e e a six
# Decoded:
# g o e  sx
# Original:
# t a n g l e w y l d e
# Decoded:
# t      w y l e
# Original:
# m f g i k two sixty
# Decoded:
#  f  i  tw sixty
# Original:
# t r a c y
# Decoded:
# t  c y
# Original:
# repeat
# Decoded:
# ret
# Original:
# four two two two oh eight nine
# Decoded:
# four two two two oh eight nine
# Original:
# erase a l h n c thirty five
# Decoded:
# rs  l   c thr five
# Original:
# w a t e r b u r y
# Decoded:
# w t r b u r y
# Original:
# w h i t n e y
# Decoded:
#  i tn y
# Original:
# no
# Decoded:
# n
# Original:
# enter two five four six
# Decoded:
# ntr two five four six
# Original:
# thirty one j a n u a r y one nine seven zero
# Decoded:
# ther one    u  r y one nine seven zer
# Original:
# no
# Decoded:
# on
# Original:
# r a n d y
# Decoded:
# r  n y
# Original:
# enter fifty sixty three
# Decoded:
# nter tfty sixty thre
# Original:
# six seventeen thirty six
# Decoded:
# six seven tien tir seix
# Original:
# stop
# Decoded:
# sto
# Original:
# no
# Decoded:
# o
# Original:
# h i n i c h
# Decoded:
#  i n i c
# Original:
# s e w i c k l e y
# Decoded:
# s   w y c   l y
# Original:
# enter one forty two
# Decoded:
# enthr one for two
# Original:
# s e p t e m b e r one two one nine five nine
# Decoded:
# s  g t l  v r one two one ine five nine
# Original:
# erase v y w l r seven zero one one
# Decoded:
# es v y w l r seven ero one one
# Original:
# six eight three three seven eight zero
# Decoded:
# six eight thre thre seven eight zero
# Original:
# h o b a r t
# Decoded:
#  l b  r t
# Original:
# erase v r f o five
# Decoded:
# era  t rf o five
# Original:
# p i t t s b u r g h
# Decoded:
# p t  s  u r g
# Original:
# j c h e q fifty eight thousand nine thirty nine
# Decoded:
# j c h g g fty eight n nine thir nine
# Original:
# e l l s w o r t h
# Decoded:
#  l  s w  r t
# Original:
# stop
# Decoded:
# st
# Original:
# erase w f s o l eight four four
# Decoded:
# ers w f s ol e four four
# Original:
# enter zero
# Decoded:
# nter zero
# Original:
# m a c a l u s o
# Decoded:
# n  c  l  s
# Original:
# one oh six
# Decoded:
# one o six
# Original:
# a s b u r y p l a c e
# Decoded:
#  s b  r y  l  c
# Original:
# sixty three sixty four and a half
# Decoded:
# sixty thre sixty four ni n
# Original:
# three four eight zero
# Decoded:
# thre four eih tro
# Original:
# stop
# Decoded:
# top
# Original:
# w c v y h seventy seven forty four
# Decoded:
# tw c d y h seventy seven forty four
# Original:
# erase c b j v c thirty five
# Decoded:
# erase c    c thir five
# Original:
# p i t t s b u r g h
# Decoded:
#  tt s b u r g
# Original:
# s t e e r e
# Decoded:
# s  e r
# Original:
# n g n n three nine nine
# Decoded:
#  g n n thre nine nine
# Original:
# j a m e s
# Decoded:
# g n  s
# Original:
# stop
# Decoded:
# sto
# Original:
# september first nineteen sixty nine
# Decoded:
# sevete first nineten sixty nine
# Original:
# f e n n i m o r e
# Decoded:
# ef n n i m  r
# Original:
# no
# Decoded:
# o
# Original:
# h o b a r t
# Decoded:
# eh o b r t
# Original:
# one five two one oh
# Decoded:
# one five two one o
# Original:
# b o x eight oh seven
# Decoded:
#  o s eigh o seven
# Original:
# nine one four three three seven one eight six nine
# Decoded:
# nine one four thre twre seven one eigh six ne
# Original:
# four one two five two one five three three nine
# Decoded:
# four one two five two one five thre thre nine
# Original:
# rubout o q i m i thirty two
# Decoded:
# rubout  t in i thrty to
# Original:
# rubout n a f k v thirty
# Decoded:
# rubout n f  d thir
# Original:
# s a y b r o o k h a r b o r
# Decoded:
# s  y  r o o k h  r b o
# Original:
# r g c s seven sixty seven
# Decoded:
#  r g c s seven sixty seven
# Original:
# n l n s one seventy five
# Decoded:
# n l n s one sen five
# Original:
# four two two zero seven nine one
# Decoded:
# four two two zer seven nine one
# Original:
# one five two oh six
# Decoded:
# one five two o six
# Original:
# rubout u t d a two
# Decoded:
# rubout  t d  two
# Original:
# eight eight two eight one oh two
# Decoded:
# h eh two eight one o two
# Original:
# j o s e p h
# Decoded:
#  os   h
# Original:
# m a r g a r e t
# Decoded:
#   r  t  r e  t
# Original:
# one five two one seven
# Decoded:
# one five two one seven
# Original:
# enter eight thirty two
# Decoded:
# nter eight thr two
# Original:
# p i t t s b u r g h
# Decoded:
# p  t t s e u r g
# Original:
# june eleventh nineteen sixty seven
# Decoded:
# t o neentw ninet sixty seven
# Original:
# enter forty seven forty seven
# Decoded:
# eter fort seven fourt seven
# Original:
# z c b e g seventy nine
# Decoded:
# e c   z seventy nine
# Original:
# v e c c h i
# Decoded:
#   c z  i
# Original:
# h o y
# Decoded:
# eh o  y
# Original:
# rubout z o t f two
# Decoded:
# ubout c o t f two
# Original:
# enter nine eight nine
# Decoded:
# nter nine eight nine
# Original:
# one five two three nine
# Decoded:
# one in t thre nine
# Original:
# enter fourteen
# Decoded:
# ter four te
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s  u r g
# Original:
# help
# Decoded:
# lpe
# Original:
# one five oh four four
# Decoded:
# one five oh four four
# Original:
# b u r k s
# Decoded:
# e  r  s
# Original:
# one nine oh oh eight
# Decoded:
# one ine o oeight
# Original:
# nine three five oh six nine two
# Decoded:
# ninethre five oh six nine two
# Original:
# j v p e eight seven zero
# Decoded:
#   t e eigh seven ze
# Original:
# twelve twenty one fifty eight
# Decoded:
# woe twnt one tfwty eight
# Original:
# j o h n
# Decoded:
# j o
# Original:
# nine four oh eight six
# Decoded:
# none four oh eight se
# Original:
# one five two zero six
# Decoded:
# one five two zer six
# Original:
# p i t t s b u r g h
# Decoded:
#  i t t s  u r g h
# Original:
# c r a f t o n
# Decoded:
# c r f t o
# Original:
# s t e v e n
# Decoded:
# s t e e e n
# Original:
# p i t t s b u r g h
# Decoded:
#  i tt   u r g h
# Original:
# enter sixty
# Decoded:
# nter sixty
# Original:
# m a r g a r e t
# Decoded:
# n  r g  r  t
# Original:
# t o m
# Decoded:
# p o on
# Original:
# w r i g h t s v i l l e
# Decoded:
# w r i g t s v i l l
# Original:
# enter seven
# Decoded:
# eter seven
# Original:
# no
# Decoded:
# o
# Original:
# no
# Decoded:
# o
# Original:
# rubout t b p b six
# Decoded:
# rubout t v  v six
# Original:
# rubout u j m k nine
# Decoded:
# rubout u  m ni
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s b e r g
# Original:
# erase x b m n t four one oh nine
# Decoded:
# er sc  w n t four one one nine
# Original:
# o a m j one five three
# Decoded:
# oh    one five thre
# Original:
# s u n n y v a l e
# Decoded:
# s u  n y v  l
# Original:
# one five two zero seven
# Decoded:
# one five two zero seven
# Original:
# p t q d q one
# Decoded:
# p t g   one
# Original:
# p i t t s b u r g h
# Decoded:
#  i t t s b u r g h
# Original:
# one ten
# Decoded:
# one ten
# Original:
# two ten
# Decoded:
# two ten
# Original:
# e a s t e n d a v e n u e
# Decoded:
#  s t e n  d v  n
# Original:
# rubout j u i p three two eight
# Decoded:
# ubo   y  twretwo eih
# Original:
# go
# Decoded:
#
# Original:
# stop
# Decoded:
# so
# Original:
# f r a n z i n i
# Decoded:
# f r  n z i n i
# Original:
# r i c h a r d
# Decoded:
# r i c   r z
# Original:
# rubout o k t l e two eight one
# Decoded:
# ruout o k t l b two eight foune
# Original:
# six three eight
# Decoded:
# six thre eght
# Original:
# j e a n e t t e
# Decoded:
#   n e t t
# Original:
# g r o s s m a n
# Decoded:
# p r o s s m  n
# Original:
# one five two one seven
# Decoded:
# one five two ne seven
# Original:
# july twenty nine nineteen sixty nine
# Decoded:
#  y twrnt nine ninete ixty n
# Original:
# s o u t h
# Decoded:
# s ou th
# Original:
# c l o u t i e r
# Decoded:
# c l o u t i e
# Original:
# n e w b u r y
# Decoded:
# n w bu r y
# Original:
# p o u n b five
# Decoded:
# p ou  b five
# Original:
# one fifty
# Decoded:
# one fiwoty
# Original:
# enter sixty one
# Decoded:
# enter sixty on
# Original:
# p o l i f r o n i
# Decoded:
# p o l y r o m i
# Original:
# two six eight four six seven eight
# Decoded:
# two six eight four six seneight
# Original:
# n i c o l e
# Decoded:
# efi c  l
# Original:
# g i b s o n i a
# Decoded:
# g i b s o n i a
# Original:
# one two seven six three
# Decoded:
# one two seven six thr
# Original:
# d a l z e l l
# Decoded:
# p  l z  l l
# Original:
# august twenty fourth nineteen fifty two
# Decoded:
# oe twenty four t ninete fifty two
# Original:
# p a t t e r s o n
# Decoded:
# p  t t r s on
# Original:
# enter sixty
# Decoded:
# nter sixty
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s b  u r g h
# Original:
# enter two
# Decoded:
# nter two
# Original:
# rubout f b m j seven ten
# Decoded:
# rubout     seven teien
# Original:
# enter seventy eight
# Decoded:
# nter seventy eight
# Original:
# eighteen february nineteen seventy
# Decoded:
# h t firre nine ten seven t
# Original:
# five six one five
# Decoded:
# five six one five
# Original:
# oh seven nine two two
# Decoded:
# v seven nine twot
# Original:
# two seven nine two three two four
# Decoded:
# two seven nine two thre two four
# Original:
# rubout m v o o forty six
# Decoded:
# rubout  v o o forty six
# Original:
# a l t m a n n
# Decoded:
# l t   n n
# Original:
# three oh eight five
# Decoded:
# thre oh eight five
# Original:
# r e w y eight five six
# Decoded:
# r e w y ih five six
# Original:
# one four eight two three
# Decoded:
# one four eight two thre
# Original:
# c e n t r e a v e
# Decoded:
# c  n t r v  v
# Original:
# yes
# Decoded:
# s
# Original:
# august sixteenth nineteen sixty five
# Decoded:
# ov sixty tntee sixty five
# Original:
# a t t g k eighty four
# Decoded:
#  t t g h four
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s b u r g
# Original:
# five six three one
# Decoded:
# five six thre one
# Original:
# p o m e r a n t z
# Decoded:
# p    r  t z
# Original:
# three six one zero one five five
# Decoded:
# thre six one zero one five five
# Original:
# o r c h a r d p l a c e
# Decoded:
# l r c h  r b t  l  c
# Original:
# one five two three two
# Decoded:
# one five two thre two
# Original:
# five five three five
# Decoded:
# five five thre five
# Original:
# t r e n t o n
# Decoded:
# t r n t o n
# Original:
# e a s t eighty fifth s t r e e t
# Decoded:
# es t h fe sty r e t
# Original:
# enter six oh eight oh
# Decoded:
# entr six oh eight oh
# Original:
# h k t e d one seventy
# Decoded:
# eh  t d one seven
# Original:
# enter five zero
# Decoded:
# nter five zero
# Original:
# enter thirty five
# Decoded:
# nter thir five
# Original:
# v f o f h nine four
# Decoded:
#  fs o f h nine four
# Original:
# s f q q k six thousand eight hundred and eighty one
# Decoded:
# s f g  k six on eight oinr n eight one
# Original:
# p i t t s b u r g h
# Decoded:
#  i t t s v u r g
# Original:
# six six one nine eight eight four
# Decoded:
# six six one nine eight eight four
# Original:
# p g h
# Decoded:
#  g
# Original:
# p i t t s b u r g h
# Decoded:
# p i g g s b u r g h
# Original:
# rubout o h g p d two nine seven six
# Decoded:
# rubout o   g  two nin seven six
# Original:
# four two one six two eight three
# Decoded:
# four two one six tho eigh three
# Original:
# m e a d o w g a t e d r i v e
# Decoded:
# n e h b n w  g  t e t r i v
# Original:
# l i n d a
# Decoded:
# l i n
# Original:
# repeat
# Decoded:
# rei
# Original:
# m o h n k e r n
# Decoded:
# mo h  k r
# Original:
# five two one four nine five four
# Decoded:
# fivetw one fun nine five four
# Original:
# four one two five two one eight two six oh
# Decoded:
# four one two five two one eight two six oh
# Original:
# one five two oh six
# Decoded:
# one five two oh six
# Original:
# o l k f five forty five
# Decoded:
# o l  five forty five
# Original:
# yes
# Decoded:
# s
# Original:
# m o d u g n o
# Decoded:
# n oi d  u g o
# Original:
# yes
# Decoded:
# bs
# Original:
# one zero zero six
# Decoded:
# one  zeo er six
# Original:
# erase y b e j q five oh seven
# Decoded:
# rse y e e  g fiveon seven
# Original:
# rubout h w o n j four thousand seven hundred twenty three
# Decoded:
# rubout i w l m k four teo seven oh wonty thre
# Original:
# p g h
# Decoded:
# p g h
# Original:
# three twenty seven sixty eight
# Decoded:
# ere fiwvnt seven sixty eight
# Original:
# g l l k h one
# Decoded:
# g l l k h one
# Original:
# ten thirty one fifty eight
# Decoded:
# n threy one fifty eightt
# Original:
# enter one thirty one
# Decoded:
# enter one thirty one
# Original:
# b r o o m a l l
# Decoded:
# b r o o n  l
# Original:
# repeat
# Decoded:
# ret
# Original:
# rubout g j h g v seven
# Decoded:
# ubout g  h  v seven
# Original:
# five twenty six forty five
# Decoded:
# five twenty six torty five
# Original:
# g w n l l nine four
# Decoded:
# g   l l in four
# Original:
# h p d f t sixty three
# Decoded:
# h  b t ixty shre
# Original:
# h a n d e r s o n
# Decoded:
# h n d  r s o
# Original:
# b y v m eight four
# Decoded:
#  y  h four
# Original:
# one five two three two
# Decoded:
# one five two thre two
# Original:
# one five two one eight
# Decoded:
# one five two one eight
# Original:
# s w i s s v a l e
# Decoded:
# s w i s s v  l e
# Original:
# start
# Decoded:
# shr
# Original:
# two four two two nine one two
# Decoded:
# two four two two nine one two
# Original:
# m e m o r y l a n e
# Decoded:
#  l  y l  n
# Original:
# b l a c k w o o d
# Decoded:
#   l  c k w o o b
# Original:
# erase m y a m seven
# Decoded:
# erse  y  sen
# Original:
# enter eight one nine six
# Decoded:
# nter eight one nine six
# Original:
# five two one sixty fifty five
# Decoded:
# five two one sixty fifty five
# Original:
# erase s s w z nine
# Decoded:
# rase s s w z ine
# Original:
# december eighteenth nineteen forty four
# Decoded:
# b sever eightten thnte fourty four
# Original:
# e r i k
# Decoded:
#  r i k
# Original:
# repeat
# Decoded:
# ret
# Original:
# f i y q fifty six
# Decoded:
# f i y g fty six
# Original:
# nine two two seven two two zero
# Decoded:
# nine two two seven two two zi o
# Original:
# rubout u t f f eight
# Decoded:
# rubout  t f f
# Original:
# yes
# Decoded:
# s
# Original:
# july thirtieth nineteen sixty five
# Decoded:
#  y thir t ninetee sixy five
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s b u r g
# Original:
# five one one five
# Decoded:
# fve o one five
# Original:
# l e w i s
# Decoded:
# l   i s
# Original:
# enter five two four
# Decoded:
# nter fivetwo four
# Original:
# a m y
# Decoded:
#  m y
# Original:
# rubout w l f x y seven oh six nine
# Decoded:
# rubout ol f s y sive n o six ine
# Original:
# enter sixty one
# Decoded:
# nter sixty one
# Original:
# erase s v n y ten ten
# Decoded:
# rse s g n y te tn
# Original:
# enter eight twenty seven
# Decoded:
# nt e twenty seven
# Original:
# b r e n n a n
# Decoded:
#   r  nn
# Original:
# s w a r t z
# Decoded:
# s   r  z
# Original:
# one two zero
# Decoded:
# one two zr on
# Original:
# help
# Decoded:
# l
# Original:
# b r o a d h e a d r o a d
# Decoded:
# b r o d     r o b
# Original:
# four oh three
# Decoded:
# our on thir
# Original:
# september sixth nineteen sixty seven
# Decoded:
# sixto sixt nine t sixty seven
# Original:
# two nine six six two
# Decoded:
# two nine six six two
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s u r g
# Original:
# four one two six eight seven eight eight seven one
# Decoded:
# four one two six eight seven eightteight seven oe
# Original:
# s k e e s
# Decoded:
# s k e e s
# Original:
# repeat
# Decoded:
# e t
# Original:
# a g l g a six four nine
# Decoded:
#  g l g  six four nine
# Original:
# stop
# Decoded:
# so
# Original:
# five two seven
# Decoded:
# five two seven
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s v u r g h
# Original:
# rubout m n z l three seven seven
# Decoded:
# rbou t  z l thre sen seven
# Original:
# l e u l i e t t e
# Decoded:
#  e u l i  t t
# Original:
# erase q e j q t seventy seven
# Decoded:
# eurse g e k  t sexnty seven
# Original:
# i p a c f two five eight
# Decoded:
# i   c  two five eight
# Original:
# b e a c o n
# Decoded:
#    c
# Original:
# enter fifty four
# Decoded:
# efity four
# Original:
# rubout z y t l fifty one
# Decoded:
# ouout   y t l fty one
# Original:
# one five two three two
# Decoded:
# one five twothre two
# Original:
# p i t t s b u r g h
# Decoded:
#  i t t s b u r g h
# Original:
# erase j n r g forty eight
# Decoded:
# e rse kn r g fort eightte
# Original:
# eight eight four one zero five seven
# Decoded:
#  gh four one er o five sen
# Original:
# c o n n e l l y
# Decoded:
# c o n  e l l y
# Original:
# p t k x zero
# Decoded:
# p t k  o
# Original:
# s u o u eighty six
# Decoded:
# s  o eu eih six
# Original:
# one five two one seven
# Decoded:
# one five two one seven
# Original:
# start
# Decoded:
# strt
# Original:
# enter sixty four
# Decoded:
# etr sixty four
# Original:
# start
# Decoded:
# sttr
# Original:
# m a t t h e w
# Decoded:
# m  t t h t w
# Original:
# s t e v e n
# Decoded:
# s t e
# Original:
# five six four zero
# Decoded:
# five six fort ero
# Original:
# v a l e
# Decoded:
# p l
# Original:
# help
# Decoded:
# l
# Original:
# rubout r e f v s one five three three
# Decoded:
# rubout r e f  s one five thre thr
# Original:
# three fourteen sixty seven
# Decoded:
# thre fourteen sixty seven
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s v  r g h
# Original:
# w e i d e
# Decoded:
# o  i b
# Original:
# rubout o g d e four seven five seven
# Decoded:
# oio  z  t fort sen fie teve
# Original:
# one five two two one
# Decoded:
# one five two two one
# Original:
# v q d b forty nine hundred
# Decoded:
#  t t t b frt nine nee
# Original:
# fifty six thirty two
# Decoded:
# fwot six teir two
# Original:
# enter seventy one
# Decoded:
# enter sieventy one
# Original:
# august twenty second nineteen sixty nine
# Decoded:
# our tent sexn eineten sixty nine
# Original:
# two six eight three zero six six
# Decoded:
# two six eight thre zero six six
# Original:
# enter five
# Decoded:
# nter five
# Original:
# enter seventy two
# Decoded:
# e seven two
# Original:
# s t e p h e n
# Decoded:
# s t  h tn
# Original:
# r o b e r t
# Decoded:
# r o  e r t
# Original:
# seven nine three five four two nine
# Decoded:
# seven nine thre five four two nine
# Original:
# one five one four seven
# Decoded:
# one five one four seven
# Original:
# b a i q w eight
# Decoded:
#   i t   egh
# Original:
# x z i v y one
# Decoded:
# s y i y ne
# Original:
# nine twenty three sixty three
# Decoded:
# nine twty thre scxty three
# Original:
# rubout u f z z sixty nine
# Decoded:
# ruboit  n z  sixty nie
# Original:
# start
# Decoded:
# r
# Original:
# f r a n c e s m a r y
# Decoded:
#  r  n c e s   h r y
# Original:
# erase o j t k s thirty five
# Decoded:
# s o  t  s thry five
# Original:
# p h y l l i s
# Decoded:
# p  y  l i s
# Original:
# k u n t z
# Decoded:
#  n
# Original:
# rubout c h y d d oh
# Decoded:
# ubout c h y  d o
# Original:
# twelve four sixty seven
# Decoded:
# l four sixty seven
# Original:
# j e f f
# Decoded:
#   f f
# Original:
# a y l e s b o r o
# Decoded:
#  y l  s  o r o
# Original:
# four one two six eight seven nine five two six
# Decoded:
# four one two six eight seven nine five two six
# Original:
# enter four twenty one
# Decoded:
# enter four twntwo one
# Original:
# enter six one two five
# Decoded:
# enr six one two five
# Original:
# enter one nine
# Decoded:
# nter one nine
# Original:
# k a r l a
# Decoded:
#   r l
# Original:
# g l e n n
# Decoded:
# g l e n n
# Original:
# n e l s o n
# Decoded:
#  l
# Original:
# yes
# Decoded:
# es
# Original:
# h a s t i n g s
# Decoded:
# h   s t i n g s
# Original:
# enter two oh seven
# Decoded:
# etere two h seven
# Original:
# two one two five seven oh two seven eight four
# Decoded:
# two one two five sven oh two seven eight four
# Original:
# no
# Decoded:
# o
# Original:
# two six eight four one six one
# Decoded:
# two six eiht four one six twn
# Original:
# e a s t e n d
# Decoded:
#   s t  n b
# Original:
# one sixteen forty eight
# Decoded:
# one sixtyen forty eight
# Original:
# four seven sixty four
# Decoded:
# four seven sixty four
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s b r g h
# Original:
# s z k w w two thirty seven
# Decoded:
# s   wo  o  tw  teve
# Original:
# four four three six three one two
# Decoded:
# our four three six thr one two
# Original:
# j s p s z nine six nine
# Decoded:
# s e s b nine sixt ine
# Original:
# one five two three two
# Decoded:
# one five two thre two
# Original:
# m a r n e l l
# Decoded:
# m
# Original:
# v e r o n a
# Decoded:
#  r o n
# Original:
# twelve twenty four sixty eight
# Decoded:
# we twnt four sixty eight
# Original:
# one oh two
# Decoded:
# one oh two
# Original:
# q c j k eight five eight
# Decoded:
# g zc k k igh five eight
# Original:
# b e v e r l y
# Decoded:
# b  g r l y
# Original:
# two six eight three zero two seven
# Decoded:
# tw six eight thre z two seven
# Original:
# p g h
# Decoded:
# p t
# Original:
# enter ninety eight twenty eight
# Decoded:
# nter ninety eight tiwnty eight
# Original:
# four five two eight five one eight
# Decoded:
# for five two eight five one eight
# Original:
# one five two one three
# Decoded:
# one five two one thr
# Original:
# j o n a t h a n
# Decoded:
# j o y  t h n
# Original:
# g i b b s
# Decoded:
# g i b b s
# Original:
# eight two six eight six eight seven
# Decoded:
# eih two six eight six eight seven
# Original:
# go
# Decoded:
# l
# Original:
# one five two one seven
# Decoded:
# one five tw one seven
# Original:
# four four one one seven two four
# Decoded:
# four four one one seven two four
# Original:
# five two five five five
# Decoded:
# five two five five five
# Original:
# v e r k e thirty five thirty
# Decoded:
# e  r   thrt five hir
# Original:
# one five oh one five
# Decoded:
# one five oh one five
# Original:
# u s i q n seventy one
# Decoded:
# u s i g n seventy one
# Original:
# fifty one fifty six
# Decoded:
# fife nine fifty six
# Original:
# enter ninety four
# Decoded:
# er nine four
# Original:
# one five two one seven
# Decoded:
# one five two one seven
# Original:
# n e w y o r k
# Decoded:
# n   y o r
# Original:
# yes
# Decoded:
# f
# Original:
# help
# Decoded:
#
# Original:
# two six eight three eight zero two
# Decoded:
# tw sixtight thre eight zcr two
# Original:
# j e a n
# Decoded:
#
# Original:
# j z a p seventeen
# Decoded:
#  z  t seventee
# Original:
# october first nineteen sixty nine
# Decoded:
# ter fir eeinte sixty nine
# Original:
# stop
# Decoded:
# stp
# Original:
# repeat
# Decoded:
# ret
# Original:
# b r o s t
# Decoded:
#  r o s t
# Original:
# oh six seven oh eight
# Decoded:
# o six seve o eigh
# Original:
# rubout m d m t g nine six seven oh
# Decoded:
# ruout   n   nine six seven oh
# Original:
# one two five two
# Decoded:
# one two five two
# Original:
# p h i l l i p s
# Decoded:
# p  i l l i  s
# Original:
# one five two one three
# Decoded:
# one five two one thre
# Original:
# b j x k twenty three
# Decoded:
#   s k fiet thre
# Original:
# two six eight three oh five four
# Decoded:
# two six eight thre oh five four
# Original:
# t i m m
# Decoded:
# p i
# Original:
# erase t m a z x two thousand five hundred and fifty two
# Decoded:
# errs t    s t teu n five tenn tity two
# Original:
# one ten
# Decoded:
# one then
# Original:
# oh six oh seven six six
# Decoded:
# o six o seven six six
# Original:
# x g i c two
# Decoded:
# s g i c two
# Original:
# erase o t e b seventy nine
# Decoded:
# erse o t e e seventy nine
# Original:
# p i t t s b u r g h
# Decoded:
# tp i t t s b u r
# Original:
# a s p n e s
# Decoded:
#  s v   s
# Original:
# go
# Decoded:
# o
# Original:
# c l a r k
# Decoded:
# c   r k
# Original:
# j e n n i f e r
# Decoded:
#  n  t r
# Original:
# go
# Decoded:
# o
# Original:
# e r i c
# Decoded:
# e r i c
# Original:
# e l g i n
# Decoded:
# el g i
# Original:
# m o r e w o o d
# Decoded:
# m o r w  o d
# Original:
# p i t t s b u r g
# Decoded:
# p i t t ls b  r g
# Original:
# h z a e three seven five one
# Decoded:
#   z  e thre seven five one
# Original:
# rubout t g j w b seventy nine fifty nine
# Decoded:
# rubout t g k w b seventy nine fifty nine
# Original:
# twelve nine of sixty
# Decoded:
# wletn nine n sixtye
# Original:
# go
# Decoded:
# o
# Original:
# two six eight five five two four
# Decoded:
# two six eight five five two four
# Original:
# k a r l
# Decoded:
#   r l
# Original:
# m i d w o o d
# Decoded:
#  i d w o o d
# Original:
# help
# Decoded:
# lp
# Original:
# enter seven seven
# Decoded:
# thr seven seive
# Original:
# yes
# Decoded:
# es
# Original:
# five one one five m a r g a r e t
# Decoded:
# v on one fiv m  r g  r  t
# Original:
# e r i c
# Decoded:
# p r i scx
# Original:
# s l e e p y h o l l o w
# Decoded:
# s l   b y  o l l o w
# Original:
# repeat
# Decoded:
# ret
# Original:
# c h r i s
# Decoded:
# c h r i s
# Original:
# p i t t s b u r g h
# Decoded:
# t i t t s b u r g
# Original:
# two four three eight three two eight
# Decoded:
# two four three eight thre two eigh
# Original:
# f a r r e l l y
# Decoded:
# f  r r e l l y
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s bu r g
# Original:
# three two seven
# Decoded:
# thre e two seven
# Original:
# ten twelve sixty seven
# Decoded:
# ten twe sixty seven
# Original:
# one twenty two
# Decoded:
# one twenty two
# Original:
# one five two one seven
# Decoded:
# one five two one seven
# Original:
# seven thirty
# Decoded:
# seve thry
# Original:
# f o r w a r d
# Decoded:
# tf o r w
# Original:
# z e l i e n o p l e
# Decoded:
# c  l i e   l
# Original:
# rubout f m q n h three seventy
# Decoded:
# ruout f    h thre seventeo
# Original:
# g i b s o n i a
# Decoded:
# g i b s o  i
# Original:
# no
# Decoded:
# no
# Original:
# fifty one fifteen
# Decoded:
# t one fewo tn
# Original:
# enter forty one
# Decoded:
# nter forty one
# Original:
# a l l e v a
# Decoded:
#  l l v
# Original:
# area code four one two four two two one two two five
# Decoded:
# r o four one two four two two one two two five
# Original:
# c a r r e l
# Decoded:
# c  r r g l
# Original:
# one five two two one
# Decoded:
# one five two two one
# Original:
# w a r d
# Decoded:
# w r d
# Original:
# stop
# Decoded:
# fp
# Original:
# repeat
# Decoded:
# re
# Original:
# seven four one oh five nine two
# Decoded:
# seven four one oh five nine two
# Original:
# ten one sixty eight
# Decoded:
# tte on sixty eght
# Original:
# six five three four
# Decoded:
# six five thre fou
# Original:
# l u d w i c k
# Decoded:
# o u b w y c
# Original:
# s e m p l e
# Decoded:
# s  m  l
# Original:
# twelve nineteen sixty nine
# Decoded:
# wpnineten sixty nine
# Original:
# one five two one three
# Decoded:
# one five two one thre
# Original:
# enter fifteen
# Decoded:
# e tiftyen
# Original:
# three seventy one
# Decoded:
# thre seventy one
# Original:
# c z d z w eight
# Decoded:
# cz z z w
# Original:
# one five three two
# Decoded:
# one five thre to
# Original:
# four twenty eight seventy one
# Decoded:
# four twnty eight sen one
# Original:
# s c a v i n c k y
# Decoded:
# s c  e i n c  y
# Original:
# p u s k a r
# Decoded:
# t u s   r
# Original:
# m o r e w o o d
# Decoded:
# oo r  w  o o b
# Original:
# t h a y e r
# Decoded:
# t h k y e r
# Original:
# o a k d a l e d r i v e
# Decoded:
# o  k d  l   r i
# Original:
# enter nine eighty nine
# Decoded:
# nter t nine eighty nine
# Original:
# m m v q d one eight seven
# Decoded:
# n m v t  one eight seven
# Original:
# m a r y j o
# Decoded:
# e r y
# Original:
# m a s o n
# Decoded:
# em   o
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s b u r
# Original:
# p i t t s b u r g h
# Decoded:
#  i t t s b  r g h
# Original:
# n n p u five
# Decoded:
# n  g u five
# Original:
# e d w i n
# Decoded:
# e b w i n
# Original:
# f k a u two four
# Decoded:
# f k u two four
# Original:
# two twenty four forty nine
# Decoded:
# two twnt four forty nine
# Original:
# d a v i d
# Decoded:
# h b
# Original:
# n e w e l l
# Decoded:
# n  w el
# Original:
# one five two three eight
# Decoded:
# one five two threeight
# Original:
# d s k u four five oh five
# Decoded:
# s k u four five o five
# Original:
# m o n i c a
# Decoded:
# m o n i c
# Original:
# c e n t r e a v e n u e
# Decoded:
# c n t r  d u e
# Original:
# fifty six oh five
# Decoded:
# ft six oh five
# Original:
# p r i n c e
# Decoded:
# p r i n c
# Original:
# l u b i n s k i
# Decoded:
# l  u  i n ks  i
# Original:
# b r u m i t t
# Decoded:
#  r u wm  t t
# Original:
# four two one oh four five one
# Decoded:
# four two one oh four five one
# Original:
# two six eight five nine five two
# Decoded:
# tw six eght five nine five two
# Original:
# p i t t s b u r g h
# Decoded:
#  i t t s y  r t
# Original:
# enter forty three forty five
# Decoded:
# nter fort thre for five
# Original:
# erase g h x w five zero four eight two
# Decoded:
# rs g h  w five zhro four eig two
# Original:
# l r r k i four
# Decoded:
# l r r k i our
# Original:
# p a r k r o a d
# Decoded:
# p  r k r o  d
# Original:
# fifty three forty two
# Decoded:
# tw thre fourty thio
# Original:
# four one two two four two six six two six
# Decoded:
# four one two two four two six si two six
# Original:
# enter sixty six
# Decoded:
# nter sixty six
# Original:
# four one two five two one two eight two four
# Decoded:
# four one two five two one two eight two four
# Original:
# stop
# Decoded:
# tp
# Original:
# h b g l seventy seven
# Decoded:
# e  g l seven seven
# Original:
# o apostrophe h a r a
# Decoded:
# wfs  h k
# Original:
# one thousand
# Decoded:
# one twnte
# Original:
# repeat
# Decoded:
# ret
# Original:
# v l c z twenty six
# Decoded:
# vl c z fwety six
# Original:
# repeat
# Decoded:
# ry
# Original:
# y d n e d forty seven
# Decoded:
# y dn d for seveon
# Original:
# rubout x c z t p four
# Decoded:
# rubout s c z t g four
# Original:
# u m n y h six
# Decoded:
#   n y gh six
# Original:
# one thousand
# Decoded:
# one teu tern
# Original:
# start
# Decoded:
# ster tw
# Original:
# one five one four three
# Decoded:
# one five one four thre
# Original:
# c m u
# Decoded:
# c n
# Original:
# e m b z six eight six
# Decoded:
#  n b z six eight six
# Original:
# one hundred
# Decoded:
# one one
# Original:
# p i t t s b u r g h
# Decoded:
#  i t t s v r g h
# Original:
# one five one one six
# Decoded:
# one five oe one six
# Original:
# enter sixty two thirty one
# Decoded:
# ntr sixty two thr one
# Original:
# three one two
# Decoded:
# thre one two
# Original:
# six zero one five
# Decoded:
# six z one five
# Original:
# f i n d l e y d r i v e
# Decoded:
# f i n  l b i e r i e e
# Original:
# yes
# Decoded:
# ns
# Original:
# b e e l e r
# Decoded:
#    l  r
# Original:
# eight four six seven
# Decoded:
# eih four six seven
# Original:
# p i t t s b u r g h
# Decoded:
# p   t t s e u r gh
# Original:
# e a s t e n d a v e
# Decoded:
#  s t en d  v
# Original:
# b e a c o n
# Decoded:
# b s o
# Original:
# erase k j z f m fifty four
# Decoded:
# ers k k z f  fwty four
# Original:
# g a r l a n d
# Decoded:
# g   r l  n
# Original:
# s a t t e r f i e l d
# Decoded:
# s  t t e r f  i l
# Original:
# enter nine seventy two
# Decoded:
# enter nine seventy two
# Original:
# thirty two thirty one
# Decoded:
# heir two hry oh
# Original:
# a m s j seven thousand one hundred and eighty six
# Decoded:
# m s  seven othn one enn eight six
# Original:
# start
# Decoded:
# tr
# Original:
# d o w n i n g t o w n
# Decoded:
# p o  n i n  t o n
# Original:
# a r a p a h o e
# Decoded:
#  r  g   o e
# Original:
# five sixteen sixty nine
# Decoded:
# five sixtyn sixty nine
# Original:
# two seven one zero eight two six
# Decoded:
# tiwo seven one zr oh eight t six
# Original:
# enter fifty one
# Decoded:
# nter fifty one
# Original:
# stop
# Decoded:
# to
# Original:
# one five six six eight
# Decoded:
# one five six six eight
# Original:
# m a r k
# Decoded:
# m r k
# Original:
# stop
# Decoded:
# so
# Original:
# yes
# Decoded:
# es
# Original:
# rubout h a x x n six seven nine one
# Decoded:
# rubout   s s n six seven nine one
# Original:
# one five two one three
# Decoded:
# one five two one thre
# Original:
# four one two six eight one one eight four two
# Decoded:
# four one two six et one on eig four two
# Original:
# erase r b d k t fifty
# Decoded:
# erse r p z  t fty
# Original:
# rubout c y r b seven eight
# Decoded:
# rubout c y r b seven eight
# Original:
# one five one oh six
# Decoded:
# one five on oh six
# Original:
# c a l i g i u r i
# Decoded:
# c  l i  d i u r r
# Original:
# yes
# Decoded:
# s
# Original:
# w i l k i n s
# Decoded:
# w yl  i ns
# Original:
# one five two one seven
# Decoded:
# one five two one seven
# Original:
# six eight one seven seven five two
# Decoded:
# six eight one seven seven five twor
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s e u r g
# Original:
# b u c k w h e a t
# Decoded:
# b vu c k   g  t
# Original:
# v a n d e r l a a n
# Decoded:
#   n e rl  h n
# Original:
# j a m e s
# Decoded:
# p  n e s
# Original:
# stop
# Decoded:
# o
# Original:
# a g l g a six hundred forty nine
# Decoded:
#   t o g  six tenre fort nine
# Original:
# p i n e h u r s t
# Decoded:
# p y n b  eu r s t
# Original:
# f y z o two two two
# Decoded:
# f y  z i tw two two
# Original:
# four two one oh one nine six
# Decoded:
# four two one oh one ne six
# Original:
# eight oh three two three four five nine seven two
# Decoded:
# igh  h three two thre four five nine seven two
# Original:
# x h b a c five three four four
# Decoded:
#  b c five thre four four
# Original:
# z i r k six four four
# Decoded:
# z  r k six four four
# Original:
# f e d o r
# Decoded:
# f e v o r
# Original:
# enter eighty nine forty three
# Decoded:
# nter eight nine forty thre
# Original:
# enter eight seven
# Decoded:
# nter eight seven
# Original:
# enter seven
# Decoded:
# nter seve
# Original:
# repeat
# Decoded:
# ret
# Original:
# one five one three three
# Decoded:
# one fve one twre thr
# Original:
# s n o w
# Decoded:
# s n o w
# Original:
# p i t t s b u r g h
# Decoded:
#  i t  s e u r gh
# Original:
# s t o d o l s k y
# Decoded:
# s tg o t o  s k y
# Original:
# o l a c k
# Decoded:
# l  c
# Original:
# d a n i e l
# Decoded:
# p   i l
# Original:
# yes
# Decoded:
# es
# Original:
# one oh oh two eight
# Decoded:
# oeooh two eight
# Original:
# rubout a d e u y three sixty four
# Decoded:
# ruboutt  e u y thre sixty four
# Original:
# no
# Decoded:
# o
# Original:
# four eight four two
# Decoded:
# four eight four two
# Original:
# help
# Decoded:
# l
# Original:
# d a v i d
# Decoded:
#   b i b
# Original:
# enter two
# Decoded:
# enter two
# Original:
# one two two two
# Decoded:
# oe two two two
# Original:
# help
# Decoded:
# p
# Original:
# stop
# Decoded:
# o
# Original:
# enter ninety five
# Decoded:
# nter iney five
# Original:
# one five two one seven
# Decoded:
# one five tw one seven
# Original:
# s u m m e r l e a
# Decoded:
# s u m m  r l
# Original:
# six six five nine six six five
# Decoded:
# six six five nine six six five
# Original:
# rubout e u j o ninety five
# Decoded:
# rubout e u  l nine five
# Original:
# s h a r o n
# Decoded:
# s   r o
# Original:
# enter six two four
# Decoded:
# nter sixtwo four
# Original:
# m c k e e s p o r t
# Decoded:
# n  k s t r t
# Original:
# e w a l d
# Decoded:
#  w   v
# Original:
# go
# Decoded:
# l
# Original:
# enter eight seventy one
# Decoded:
# nter eight sevety one
# Original:
# seven three zero
# Decoded:
# seve thre zero
# Original:
# erase i s l f thirty eight
# Decoded:
# eras sl  f tfr eigh
# Original:
# y f j k two eight
# Decoded:
# y f k  two eight
# Original:
# h o w e l l
# Decoded:
#  w   el l
# Original:
# enter seven
# Decoded:
# nter seven
# Original:
# erase z y g n p eight hundred and twenty three
# Decoded:
# erse c y g n t eih n n twenty thre
# Original:
# erase e o a c u three
# Decoded:
# rse e o h c u thre
# Original:
# repeat
# Decoded:
# ret
# Original:
# yes
# Decoded:
# s
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s   u r g h
# Original:
# four one two eight three one nine five one three
# Decoded:
# four one two eight three one oine five one thir
# Original:
# erase o t h f i five zero
# Decoded:
# r se oh t h f i five zxro
# Original:
# enter six four five one
# Decoded:
# nter six four five fo ne
# Original:
# l z r v fifty five thirty five
# Decoded:
# l  r v tifty five firy five
# Original:
# yes
# Decoded:
# es
# Original:
# enter two oh five
# Decoded:
# nter two oh five
# Original:
# w a y n e
# Decoded:
# w  y n h
# Original:
# repeat
# Decoded:
# re
# Original:
# enter four
# Decoded:
# nter four
# Original:
# fourteen fourteen
# Decoded:
# four teen for tyen
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s b  r g h
# Original:
# repeat
# Decoded:
# ep
# Original:
# six eight seven five eight oh eight
# Decoded:
# six eig seven five eight h eghe
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s   u r
# Original:
# enter nine
# Decoded:
# nter nine
# Original:
# erase i g n m forty three seventeen
# Decoded:
# errse in g m forty thre seventween
# Original:
# r q z h four
# Decoded:
# r t   four
# Original:
# enter six seven
# Decoded:
# nter six seven
# Original:
# i v a r s o n
# Decoded:
# i   r son
# Original:
# two six eight four six five eight
# Decoded:
# two six eight four six five eigh
# Original:
# enter six
# Decoded:
# nter six
# Original:
# t v a h fifty two fifty three
# Decoded:
# t  h  ftytwo fty three
# Original:
# six eight three five zero four one
# Decoded:
# six eight thr five zer four one
# Original:
# enter eight zero six
# Decoded:
# entr eight zero six
# Original:
# erase q k x y u one sixty two
# Decoded:
# ra g   i one sixt two
# Original:
# june twenty third nineteen sixty nine
# Decoded:
#  twent tfir inete six tey ne
# Original:
# rubout n z x l thirty one
# Decoded:
# rubout n z s l thr one
# Original:
# one five two two six
# Decoded:
# one five two two six
# Original:
# yes
# Decoded:
# s
# Original:
# erase e x x s zero
# Decoded:
# erse t s  s zro
# Original:
# r o z e v e l d
# Decoded:
# r o z    l b
# Original:
# eleven seventeen fifty one
# Decoded:
# eol seventee fifty one
# Original:
# six twenty six sixty three
# Decoded:
# six twen six sixty thre
# Original:
# seven fourteen sixty one
# Decoded:
# seven four tn sixty one
# Original:
# four four oh six five
# Decoded:
# four four oh six five
# Original:
# l o n g v i e w
# Decoded:
# l o n  g  i e w
# Original:
# k l m u five two seven four
# Decoded:
#  l n  five t seven four
# Original:
# c a r n e g i e
# Decoded:
# c  r n   g i e
# Original:
# four four four seven
# Decoded:
# four four fourt seven
# Original:
# one nine three three five
# Decoded:
# one nine thre thre five
# Original:
# help
# Decoded:
# p
# Original:
# six six one five zero six four
# Decoded:
# six six one five ze six four
# Original:
# seven twenty nine fifty eight
# Decoded:
# seven twnty nine fity eight
# Original:
# v a d r thirty one oh seven
# Decoded:
# p  d r thr one  seven
# Original:
# m a p l e
# Decoded:
# m g l e
# Original:
# b r i a n
# Decoded:
#  r i  n
# Original:
# j h b x three zero
# Decoded:
# j  b  thre zero
# Original:
# g e e p c seven one oh seven
# Decoded:
# g v c seven one h seven
# Original:
# rubout t j j c l two
# Decoded:
# rubout t g  c l two
# Original:
# yes
# Decoded:
# s
# Original:
# one five two one three
# Decoded:
# one fivetwo one thre
# Original:
# six thirty
# Decoded:
# six thr
# Original:
# start
# Decoded:
# str
# Original:
# c e l l i o
# Decoded:
# c  l l i l
# Original:
# fifty six sixty nine
# Decoded:
# iwty six sixty nine
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s b u r gh
# Original:
# m a r k
# Decoded:
#   r k
# Original:
# yes
# Decoded:
# s
# Original:
# d y m h r sixty one
# Decoded:
# p ym  r sixty one
# Original:
# rubout v e w z seven seventy two
# Decoded:
# rubout  w z seven svey two
# Original:
# one five two one seven
# Decoded:
# one five two one seven
# Original:
# ten seventy one
# Decoded:
# ten seventy one
# Original:
# rubout i r d d j one
# Decoded:
# rubout i r b b  one
# Original:
# yes
# Decoded:
# es
# Original:
# n a t h a n
# Decoded:
# n t
# Original:
# two one five four five eight five four six nine
# Decoded:
# two one five four five eight five four six nine
# Original:
# eleven nine sixty eight
# Decoded:
# eubn nine sixty eigh
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s  u r g
# Original:
# o a w f five nine
# Decoded:
# o  w   five nine
# Original:
# one five two one seven
# Decoded:
# one five two one seven
# Original:
# v k z o sixty two
# Decoded:
# p k c o sixty two
# Original:
# six three two three
# Decoded:
# six thre two thre
# Original:
# m a h o n e y
# Decoded:
# m  o  y
# Original:
# s h e i l a
# Decoded:
# s h  ni l
# Original:
# l a m p s o n
# Decoded:
# l  m g s o  n
# Original:
# f i f t h
# Decoded:
# f i f t h
# Original:
# rubout y y f x zero
# Decoded:
# rubout y yf s r
# Original:
# erase w e s f twenty four oh three
# Decoded:
# prse w e s  twnt four oh thr
# Original:
# january fifteenth nineteen sixty three
# Decoded:
# n o tn nine te ixty thre
# Original:
# one four eight five oh
# Decoded:
# one foureight fiveo
# Original:
# t h a d
# Decoded:
# t   b
# Original:
# rubout e z u a i fifteen
# Decoded:
# rubout z u  i fte
# Original:
# e z a k o eight
# Decoded:
# e z  k o h
# Original:
# j u l i e
# Decoded:
#   l i
# Original:
# enter five three four three
# Decoded:
# nter five thre four three
# Original:
# yes
# Decoded:
# s
# Original:
# erase c k c w fourteen eighty five
# Decoded:
# eurs c  c   fourtn eight five
# Original:
# h a h l e four ninety one
# Decoded:
# h k h kl b four ine one
# Original:
# r o s e n f e l d
# Decoded:
# r o s  n f   l b
# Original:
# enter five
# Decoded:
# enter five
# Original:
# eight forty one
# Decoded:
# eigh forty one
# Original:
# b r o n x v i l l e
# Decoded:
# e r o n w  e i l l
# Original:
# w i l l i a m s
# Decoded:
# w i l l y
# Original:
# stop
# Decoded:
# sto
# Original:
# h i g h l a n d
# Decoded:
#  i g h  l  n
# Original:
# m a u l d i n
# Decoded:
#   u  l d i n
# Original:
# enter one ninety six
# Decoded:
# nter one ninety six
# Original:
# s t e v e
# Decoded:
# s t e d
# Original:
# d r a v k
# Decoded:
#  r  d
# Original:
# rubout d q t w x five hundred eighty seven
# Decoded:
# rubout d t t  w s five wn eight t seven
# Original:
# rubout r z r v z ninety eight
# Decoded:
# uou r z r v z nineeigh
# Original:
# twenty two twenty six
# Decoded:
# fwvnetee two twet six
# Original:
# k w z a g two hundred and sixty six
# Decoded:
#  o z h  tw nen sixty six
# Original:
# eight five six one four nine zero
# Decoded:
# ei five six one four nine ero
# Original:
# thirty
# Decoded:
# hr
# Original:
# four two two oh eight one six
# Decoded:
# four two two oh eight one six
# Original:
# three twelve fifty eight
# Decoded:
# hree tw fifty eight
# Original:
# march twentieth nineteen seventy
# Decoded:
# onie twnteit ninete seiveny
# Original:
# three twenty eight sixty one
# Decoded:
# re twent eight sixty one
# Original:
# m i c h a e l
# Decoded:
# m i c h   l
# Original:
# enter fifty four
# Decoded:
# nster fifty four
# Original:
# k e a n e
# Decoded:
#  n
# Original:
# g l e n s h a w
# Decoded:
# g l  n s h  w
# Original:
# eight fourteen sixty four
# Decoded:
# eih fourteen sixty four
# Original:
# go
# Decoded:
# l
# Original:
# rubout p o o b eight
# Decoded:
# rubout  o o b h
# Original:
# sixty seven ten
# Decoded:
# sixty seven teon
# Original:
# j e t t
# Decoded:
# t e t t
# Original:
# enter thirty eight sixty five
# Decoded:
# nter thiret eight sixty five
# Original:
# april thirtieth nineteen sixty nine
# Decoded:
# t fihrt tinete sixty nine
# Original:
# x i sixty one
# Decoded:
#  siv sixty one
# Original:
# one zero six five
# Decoded:
# one zio six five
# Original:
# no
# Decoded:
# no
# Original:
# six six four seven two nine three
# Decoded:
# isi four sente nine er
# Original:
# no
# Decoded:
# o
# Original:
# february eighth nineteen fifty two
# Decoded:
# ter eightse nineteen fty two
# Original:
# a l m o n t
# Decoded:
#  l m on t
# Original:
# enter three
# Decoded:
# ner three
# Original:
# f i l
# Decoded:
# f i l
# Original:
# o l d b a r n d r i v e
# Decoded:
# o o v t  rn v r i
# Original:
# repeat
# Decoded:
# ret
# Original:
# enter seven oh three eight
# Decoded:
# en ter seven h threeight
# Original:
# one five two one seven
# Decoded:
# one five two one seven
# Original:
# six sixteen sixty
# Decoded:
# six six teen six ti
# Original:
# p u x p i five
# Decoded:
# p  t i five
# Original:
# f e b one eight one nine six four
# Decoded:
#    one eight one nine six four
# Original:
# one twenty
# Decoded:
# one twvnet
# Original:
# six two five one five six four
# Decoded:
# six two five one five six four
# Original:
# s p r i n g h o u s e
# Decoded:
# s  r i n t  r s
# Original:
# g o t t i e r
# Decoded:
# p o t t i  r
# Original:
# rubout p n a m x seventy two
# Decoded:
# rubout  n   seventy two
# Original:
# m o r e w o o d
# Decoded:
# mn o r  w o o b
# Original:
# one five two oh five
# Decoded:
# one five two o une
# Original:
# october twenty third nineteen sixty seven
# Decoded:
# o twnty thr ninete sixty seven
# Original:
# no
# Decoded:
#
# Original:
# b r o w n
# Decoded:
# b r o w n
# Original:
# erase j g q y eight six one
# Decoded:
# erse  g  y igh six one
# Original:
# one five oh four four
# Decoded:
# one five o four four
# Original:
# m g e four oh two
# Decoded:
#  g  four o two
# Original:
# no
# Decoded:
# o
# Original:
# c i n d y
# Decoded:
# c i n t y
# Original:
# one five two one three
# Decoded:
# one five two one thr
# Original:
# one five two one three
# Decoded:
# one five two one thre
# Original:
# may twenty first nineteen sixty
# Decoded:
# g twent fiet ninete sixtfe
# Original:
# two fifteen sixty two
# Decoded:
# two fifte sixty two
# Original:
# p i t t s b u r g h
# Decoded:
#  i t  s  u r g
# Original:
# x e d v seven
# Decoded:
# s  b v seveon
# Original:
# f i f t h a v e n u e
# Decoded:
#  fivf t   v n u
# Original:
# d o u g l a s
# Decoded:
# p ou g l  s
# Original:
# yes
# Decoded:
# s
# Original:
# start
# Decoded:
# tpr
# Original:
# stop
# Decoded:
# stl
# Original:
# go
# Decoded:
# o
# Original:
# six eight three one five five eight
# Decoded:
# six eigh thr one five fie eight
# Original:
# yes
# Decoded:
# ps
# Original:
# v w a b w two fourteen
# Decoded:
#  w   b  two fourty
# Original:
# fifty eight oh nine and a half
# Decoded:
# fty eight oh ninen rf
# Original:
# l o o f b o u r r o w
# Decoded:
# l o f b o  u r r o w
# Original:
# enter sixty
# Decoded:
# nter sixty
# Original:
# rubout u g a m thirty nine
# Decoded:
# rubout  g  m thr nine
# Original:
# one five two one seven
# Decoded:
# one five two one seven
# Original:
# one five two one seven
# Decoded:
# one five two one seven
# Original:
# stop
# Decoded:
# sop
# Original:
# may ninth sixty two
# Decoded:
#  nin sxety two
# Original:
# start
# Decoded:
# ssr
# Original:
# h q f x four thousand three hundred and eighty six
# Decoded:
#  g f four toee thre hn eighty six
# Original:
# s p r i n g h o u s e l a n e
# Decoded:
# s b r i n g  s  l   e
# Original:
# s m i t h
# Decoded:
# s m i t h
# Original:
# m a r k
# Decoded:
# m a r
# Original:
# enter thirty seven
# Decoded:
# nter tirt seven
# Original:
# six three sixty eight
# Decoded:
# six thre sixtyeght
# Original:
# three eleven sixty seven
# Decoded:
# thre oen sxty seven
# Original:
# help
# Decoded:
# e
# Original:
# rubout j l y z two
# Decoded:
# ubout k l i z tw
# Original:
# january twelfth nineteen sixty six
# Decoded:
# jr tf ninete sixty sex
# Original:
# erase n t d i c five nine one
# Decoded:
# erras n t t nine c fve nine one
# Original:
# enter twenty nine
# Decoded:
# nter whrn nine
# Original:
# l r l y u seven three
# Decoded:
# l r lo y buu seven thre
# Original:
# n o o n b u r g
# Decoded:
# n o o n b ur g
# Original:
# n e i l
# Decoded:
# n  i l
# Original:
# nine thirty sixty five
# Decoded:
# ne thr sixty five
# Original:
# p i t t s b u r g h
# Decoded:
#  i t t s bu r g
# Original:
# enter seven two one six
# Decoded:
# nter seven two one six
# Original:
# erase v x s x two four nine nine
# Decoded:
#  s e s s s t fount nin nine
# Original:
# rubout q q q p forty five
# Decoded:
# rubout g   e fort five
# Original:
# b o u q u e t
# Decoded:
# b o g  u e t
# Original:
# r u s k i n
# Decoded:
# r eu s  y n
# Original:
# one thirty one sixty three
# Decoded:
# one thir one sixty thre
# Original:
# e a r l f o r d
# Decoded:
# e   r l f o r
# Original:
# a a i l zero
# Decoded:
#   i l iro
# Original:
# yes
# Decoded:
# s
# Original:
# help
# Decoded:
# l
# Original:
# four seven two zero
# Decoded:
# four siven two zero
# Original:
# rubout f x c w n four
# Decoded:
# ruboutu  c w n four
# Original:
# enter four thousand eight hundred eighty three
# Decoded:
# nter four totn eigh ine eight thre
# Original:
# one five two one three
# Decoded:
# one five two one three
# Original:
# one five two two one
# Decoded:
# one five w two one
# Original:
# july twelfth nineteen sixty nine
# Decoded:
# one tvet inete six nine
# Original:
# help
# Decoded:
# e
# Original:
# four oh one
# Decoded:
# four oh one
# Original:
# r h h u f two
# Decoded:
# r   f two
# Original:
# rubout n a g k k three thirty six
# Decoded:
# rubout  g   thre twr six
# Original:
# h o f f r i c h t e r
# Decoded:
#   f fir ity t  r
# Original:
# one three six
# Decoded:
# one three six
# Original:
# four eight six three nine five oh
# Decoded:
# four eight six thre nine five noh
# Original:
# enter seven
# Decoded:
# nter seven
# Original:
# one five two oh six
# Decoded:
# one five two o seix
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s b  u r  h
# Original:
# n e g l e y
# Decoded:
# n g l  y
# Original:
# k e n
# Decoded:
#   n
# Original:
# b r a d d o c k
# Decoded:
#  r  d d l c
# Original:
# september twenty seventh nineteen sixty seven
# Decoded:
# sevx twre twenty seven sx nine te sixty seven
# Original:
# p i t t s b u r g h
# Decoded:
# p i t t s b u r g h
# Original:
# enter seven
# Decoded:
# nter seven
# Original:
# b v i q g eighty six
# Decoded:
#  i t g h six
# Original:
# erase b m e e three five two
# Decoded:
# ersx b    thre five two
# Original:
# rubout j b x r z nine twenty
# Decoded:
# ubout k b  r z ne twnt
# Original:
# enter eight two four two
# Decoded:
# e igt two four to
# Original:
# j o h n s o n
# Decoded:
#  o h n s o n
# Original:
# start
# Decoded:
# ssttrt
# Original:
# d e r e k
# Decoded:
#  r
# Original:
# two oh three seven five seven eight eight nine nine
# Decoded:
# two oh thre seve five seven eight eight nine nine
# Original:
# repeat
# Decoded:
# et
# Original:
# three two seven one six nine five
# Decoded:
# thre two seven one six ne five
# Original:
# start
# Decoded:
# str
# Original:
# march third nineteen twenty eight
# Decoded:
# r ter ninete twnty eight
# Original:
# rubout i t d k m four seventy one
# Decoded:
# rubout i t  m four sevey one
# Original:
# four one two four two one eight eight nine six
# Decoded:
# four one t four two oneeighteht nine six
# Original:
# t e r i n a
# Decoded:
# t  r i
# Original:
# go
# Decoded:
# o
# Original:
# g a b h two
# Decoded:
# g  b h two
# Original:
# five two one oh two six eight
# Decoded:
# five two one oh two six eightt
# Original:
# l i n d a
# Decoded:
# i e
# Original:
# repeat
# Decoded:
# ree
# Original:
# t a y l o r
# Decoded:
# tw  y l o r
# Original:
# s t e v e n
# Decoded:
# s t  v e n
# Original:
# three oh six
# Decoded:
# thre oh six
# Original:
# c o n c o r d
# Decoded:
# c o n c o r d
# Original:
# five one nine
# Decoded:
# five one nie
# Original:
# twelve ten sixty nine
# Decoded:
# let sity nine
# Original:
# c h a r l e s
# Decoded:
# c   r  s
# Original:
# h a w t h o r n e
# Decoded:
#   w t h o r
# Original:
# four one two four two two nine eight two eight
# Decoded:
# four one two for two two n nine eight two eigh
# Original:
# d o n a l d
# Decoded:
# p o n  l v
# average wer = 2.4029535865
